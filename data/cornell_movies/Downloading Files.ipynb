# %%
# !pip install convokit
# Out:
# Collecting convokit
#   Downloading convokit-3.0.0.tar.gz (183 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.2/183.2 kB 8.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting matplotlib>=3.0.0 (from convokit)
#   Downloading matplotlib-3.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=0.23.4 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from convokit) (2.1.4)
# Collecting msgpack-numpy>=0.4.3.2 (from convokit)
#   Downloading msgpack_numpy-0.4.8-py2.py3-none-any.whl (6.9 kB)
# Collecting spacy>=2.3.5 (from convokit)
#   Downloading spacy-3.7.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: scipy>=1.1.0 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from convokit) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from convokit) (1.3.0)
# Collecting nltk>=3.4 (from convokit)
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 40.4 MB/s eta 0:00:00:00:01
# Requirement already satisfied: dill>=0.2.9 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from convokit) (0.3.7)
# Requirement already satisfied: joblib>=0.13.2 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from convokit) (1.2.0)
# Collecting clean-text>=0.6.0 (from convokit)
#   Downloading clean_text-0.6.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: unidecode>=1.1.1 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from convokit) (1.2.0)
# Requirement already satisfied: tqdm>=4.64.0 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from convokit) (4.66.1)
# Collecting pymongo>=4.0 (from convokit)
#   Downloading pymongo-4.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pyyaml>=5.4.1 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from convokit) (6.0.1)
# Collecting dnspython>=1.16.0 (from convokit)
#   Downloading dnspython-2.4.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting emoji<2.0.0,>=1.0.0 (from clean-text>=0.6.0->convokit)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 18.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ftfy<7.0,>=6.0 (from clean-text>=0.6.0->convokit)
#   Downloading ftfy-6.1.3-py3-none-any.whl.metadata (6.2 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.0.0->convokit)
#   Downloading contourpy-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.0.0->convokit)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.0.0->convokit)
#   Downloading fonttools-4.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.2/156.2 kB 13.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.0.0->convokit)
#   Downloading kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.21 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (23.1)
# Requirement already satisfied: pillow>=8 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from matplotlib>=3.0.0->convokit) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib>=3.0.0->convokit)
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting msgpack>=0.5.2 (from msgpack-numpy>=0.4.3.2->convokit)
#   Downloading msgpack-1.0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: click in /data/anaconda/envs/personality/lib/python3.9/site-packages (from nltk>=3.4->convokit) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from nltk>=3.4->convokit) (2023.10.3)
# Requirement already satisfied: pytz>=2020.1 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from pandas>=0.23.4->convokit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from pandas>=0.23.4->convokit) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from scikit-learn>=0.20.0->convokit) (2.2.0)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy>=2.3.5->convokit)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy>=2.3.5->convokit)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy>=2.3.5->convokit)
#   Downloading murmurhash-1.0.10-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy>=2.3.5->convokit)
#   Downloading cymem-2.0.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy>=2.3.5->convokit)
#   Downloading preshed-3.0.9-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.1.8 (from spacy>=2.3.5->convokit)
#   Downloading thinc-8.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy>=2.3.5->convokit)
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy>=2.3.5->convokit)
#   Downloading srsly-2.4.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy>=2.3.5->convokit)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy>=2.3.5->convokit)
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy>=2.3.5->convokit)
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 4.1 MB/s eta 0:00:00
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy>=2.3.5->convokit)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (1.10.12)
# Requirement already satisfied: jinja2 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (3.1.2)
# Requirement already satisfied: setuptools in /data/anaconda/envs/personality/lib/python3.9/site-packages (from spacy>=2.3.5->convokit) (68.2.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy>=2.3.5->convokit)
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 17.7 MB/s eta 0:00:00
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy<7.0,>=6.0->clean-text>=0.6.0->convokit)
#   Downloading wcwidth-0.2.12-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: zipp>=3.1.0 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->convokit) (3.11.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.3.5->convokit) (4.7.1)
# Requirement already satisfied: six>=1.5 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->convokit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (2023.11.17)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.1.8->spacy>=2.3.5->convokit)
#   Downloading blis-0.7.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.1.8->spacy>=2.3.5->convokit)
#   Downloading confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy>=2.3.5->convokit)
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /data/anaconda/envs/personality/lib/python3.9/site-packages (from jinja2->spacy>=2.3.5->convokit) (2.1.1)
# Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 20.3 MB/s eta 0:00:00
# Downloading matplotlib-3.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 87.8 MB/s eta 0:00:00:00:010:01
# Downloading pymongo-4.6.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (676 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 676.3/676.3 kB 45.2 MB/s eta 0:00:00
# Downloading spacy-3.7.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 90.9 MB/s eta 0:00:00:00:0100:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading contourpy-1.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.0/311.0 kB 24.6 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading cymem-2.0.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 kB 4.7 MB/s eta 0:00:00
# Downloading fonttools-4.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 84.7 MB/s eta 0:00:00:00:01
# Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 5.1 MB/s eta 0:00:00
# Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Downloading kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 73.5 MB/s eta 0:00:00
# Downloading msgpack-1.0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (530 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.0/531.0 kB 39.9 MB/s eta 0:00:00
# Downloading murmurhash-1.0.10-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Downloading preshed-3.0.9-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.5/157.5 kB 14.7 MB/s eta 0:00:00
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.1 MB/s eta 0:00:00
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.4/492.4 kB 35.8 MB/s eta 0:00:00
# Downloading thinc-8.2.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (937 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 937.7/937.7 kB 52.9 MB/s eta 0:00:00
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 5.3 MB/s eta 0:00:00
# Downloading blis-0.7.11-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 139.9 MB/s eta 0:00:0000:01
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.4 MB/s eta 0:00:00
# Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Downloading wcwidth-0.2.12-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: convokit, emoji
#   Building wheel for convokit (pyproject.toml) ... done
#   Created wheel for convokit: filename=convokit-3.0.0-py3-none-any.whl size=216707 sha256=1918b90b5ad9722f1b3f734c64971e79dc06f54945a6779998f0e98496a28b90
#   Stored in directory: /home/naomi/.cache/pip/wheels/e8/68/86/55518cc404d144b09621ec3b997719a8139d5e7738351e7a20
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=8d3382ed12687a3ae3718b22df05063f83eeec31de3c0d976562a17943226616
#   Stored in directory: /home/naomi/.cache/pip/wheels/fa/7a/e9/22dd0515e1bad255e51663ee513a2fa839c95934c5fc301090
# Successfully built convokit emoji
# Installing collected packages: wcwidth, emoji, cymem, wasabi, typer, spacy-loggers, spacy-legacy, smart-open, nltk, murmurhash, msgpack, langcodes, kiwisolver, importlib-resources, ftfy, fonttools, dnspython, cycler, contourpy, cloudpathlib, catalogue, blis, srsly, pymongo, preshed, msgpack-numpy, matplotlib, clean-text, confection, weasel, thinc, spacy, convokit
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.5
#     Uninstalling wcwidth-0.2.5:
#       Successfully uninstalled wcwidth-0.2.5
# Successfully installed blis-0.7.11 catalogue-2.0.10 clean-text-0.6.0 cloudpathlib-0.16.0 confection-0.1.4 contourpy-1.2.0 convokit-3.0.0 cycler-0.12.1 cymem-2.0.8 dnspython-2.4.2 emoji-1.7.0 fonttools-4.46.0 ftfy-6.1.3 importlib-resources-6.1.1 kiwisolver-1.4.5 langcodes-3.3.0 matplotlib-3.8.2 msgpack-1.0.7 msgpack-numpy-0.4.8 murmurhash-1.0.10 nltk-3.8.1 preshed-3.0.9 pymongo-4.6.1 smart-open-6.4.0 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.2 typer-0.9.0 wasabi-1.1.2 wcwidth-0.2.12 weasel-0.3.4

# %%
from convokit import Corpus, download

corpus = Corpus(filename=download("movie-corpus"))
# Out:
# Downloading movie-corpus to /home/naomi/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done
